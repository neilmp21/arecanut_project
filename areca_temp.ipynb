# %% [markdown]
# <a href="https://colab.research.google.com/github/neilmp21/arecanut_project/blob/main/areca_temp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/ultralytics/ultralytics
# %cd ultralytics
# !pip install -e .
# Out:
# Cloning into 'ultralytics'...
# remote: Enumerating objects: 28844, done.
# remote: Counting objects: 100% (556/556), done.
# remote: Compressing objects: 100% (355/355), done.
# remote: Total 28844 (delta 301), reused 408 (delta 200), pack-reused 28288
# Receiving objects: 100% (28844/28844), 16.76 MiB | 8.53 MiB/s, done.
# Resolving deltas: 100% (20314/20314), done.
# /content/ultralytics
# Obtaining file:///content/ultralytics
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-4617f895-ce73-464c-b7fb-93cb69980ffc" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4617f895-ce73-464c-b7fb-93cb69980ffc">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !pip install torch torchvision torchaudio
# !pip install opencv-python

# %%
# %cd /content/ultralytics
# !pip install -r requirements.txt
# Out:
# [Errno 2] No such file or directory: '/content/ultralytics'
# /content
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'requirements.txt'

# %%
# !mkdir dataset

# %%
# !unzip Arecanut.v1i.yolov8.zip -d dataset
# Out:
# Archive:  Arecanut.v1i.yolov8.zip
#  extracting: dataset/README.dataset.txt
#  extracting: dataset/README.roboflow.txt
#  extracting: dataset/data.yaml
#    creating: dataset/test/
#    creating: dataset/test/images/
#  extracting: dataset/test/images/IMG_20230308_120224_jpg.rf.46bebe80955cc7106f89e0f129e12a62.jpg
#  extracting: dataset/test/images/IMG_20230308_120329_jpg.rf.7597427e24bb1e683b64c00de41349d5.jpg
#  extracting: dataset/test/images/IMG_20230308_120408_jpg.rf.62fe563984f40d675292a7a531354e97.jpg
#  extracting: dataset/test/images/IMG_20230308_120416_jpg.rf.2ef95a8d529da58d58cbb53d0769948b.jpg
#  extracting: dataset/test/images/IMG_20230308_120426_jpg.rf.753c73666a4138352ef8372e501c6494.jpg
#  extracting: dataset/test/images/IMG_20230308_120433_jpg.rf.52b25e04e59d06b95c6e56441207f2cb.jpg
#  extracting: dataset/test/images/IMG_20230308_120533_jpg.rf.034d6247d242ac041d15bfbcab0304eb.jpg
# ...

# %%
# !python train.py --data data.yaml --weights yolov8n.pt --img 640
# Out:
# python3: can't open file '/content/ultralytics/train.py': [Errno 2] No such file or directory

# %%
ls
# Out:
# Arecanut.v1i.yolov8.zip  dataset/  sample_data/

# %%
# !git clone https://github.com/ultralytics/ultralytics
# Out:
# fatal: destination path 'ultralytics' already exists and is not an empty directory.

# %%
# %cd
# !pip install -e .
# Out:
# /content/ultralytics
# Obtaining file:///content/ultralytics
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#   Using cached ultralytics_thop-0.2.8-py3-none-any.whl (25 kB)
# ...
#   Building editable for ultralytics (pyproject.toml) ... done
#   Created wheel for ultralytics: filename=ultralytics-8.2.31-0.editable-py3-none-any.whl size=22993 sha256=bb2ef6f5b5851e560c87885353b4a7cfe4a882c668dc45a765cdcb537cd0e78f
#   Stored in directory: /tmp/pip-ephem-wheel-cache-nb336t2n/wheels/9a/cd/d5/95912172899f8ec640166ff6eef49156b1b00d6b2ade4a3cb1
# Successfully built ultralytics
# ...

# %%
# !ls /content/ultralytics
# Out:
# CITATION.cff	 docs	   mkdocs.yml	   README.zh-CN.md  ultralytics.egg-info
# CONTRIBUTING.md  examples  pyproject.toml  tests
# docker		 LICENSE   README.md	   ultralytics

# %%
# !find / -name train.py
# Out:
# find: ‘/proc/63/task/63/net’: Invalid argument
# find: ‘/proc/63/net’: Invalid argument
# /usr/local/lib/python3.10/dist-packages/dopamine/continuous_domains/train.py
# /usr/local/lib/python3.10/dist-packages/dopamine/discrete_domains/train.py
# /usr/local/lib/python3.10/dist-packages/dopamine/labs/environments/brax/train.py
# /usr/local/lib/python3.10/dist-packages/dopamine/labs/tandem_dqn/train.py
# /usr/local/lib/python3.10/dist-packages/dopamine/labs/atari_100k/train.py
# /usr/local/lib/python3.10/dist-packages/transformers/commands/train.py
# /usr/local/lib/python3.10/dist-packages/spacy/cli/train.py
# /usr/local/lib/python3.10/dist-packages/flax/nnx/examples/lm1b/train.py
# /content/ultralytics/ultralytics/models/yolo/obb/train.py
# /content/ultralytics/ultralytics/models/yolo/segment/train.py
# /content/ultralytics/ultralytics/models/yolo/classify/train.py
# /content/ultralytics/ultralytics/models/yolo/detect/train.py
# ...

# %%
# !python /content/ultralytics/ultralytics/models/yolo/classify/train.py --data /path/to/your/data.yaml --weights yolov8n.pt --img 640

# %%
# !python /content/ultralytics/ultralytics/models/yolo/classify/train.py --data /path/to/your/data.yaml --weights yolov8n.pt --img 640 --verbose

# %%
import torch
print(torch.cuda.is_available())
# Out:
# True

# %%
# !pip install -e /content/ultralytics
# Out:
# Obtaining file:///content/ultralytics
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#   Building editable for ultralytics (pyproject.toml) ... done
#   Created wheel for ultralytics: filename=ultralytics-8.2.31-0.editable-py3-none-any.whl size=22993 sha256=b88dd682045038488c365c970bda67360dc6c10403c55b7dc83e84f24a8b1383
#   Stored in directory: /tmp/pip-ephem-wheel-cache-2hyapwtd/wheels/9a/cd/d5/95912172899f8ec640166ff6eef49156b1b00d6b2ade4a3cb1
# Successfully built ultralytics
# ...
#   Attempting uninstall: ultralytics
#     Found existing installation: ultralytics 8.2.31
#     Uninstalling ultralytics-8.2.31:
#       Successfully uninstalled ultralytics-8.2.31
# ...

# %%
# !python /content/ultralytics/ultralytics/models/yolo/classify/train.py --data /path/to/your/data.yaml --weights yolov8n.pt --img 640 --verbose

# %%
# List files in the ultralytics directory to see if training results are saved
# !ls /content/ultralytics/runs/train/
# !ls /content/ultralytics/runs/train/exp
# Out:
# ls: cannot access '/content/ultralytics/runs/train/': No such file or directory
# ls: cannot access '/content/ultralytics/runs/train/exp': No such file or directory

# %%
import ultralytics
ultralytics.checks
# Out:
# <function ultralytics.utils.checks.check_yolo(verbose=True, device='')>

# %%
# !yolo classify train data=/content/ultralytics/dataset/data.yaml model=yolov8n-cls.pt epochs=1 imgsz=640
# Out:
# Ultralytics YOLOv8.2.31 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo classify train data=/content/ultralytics/dataset/data.yaml model=yolov8n-cls.pt epochs=1 imgsz=640
# Out:
# Ultralytics YOLOv8.2.31 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# Run training script with correct dataset path
# !yolo task=detect mode=train data=/content/ultralytics/datasets/data.yaml epochs=50 imgsz=640 batch=16 weights=yolov8n.pt project=/content/ultralytics/runs/train name=exp --verbose
# Out:
# WARNING ⚠️ argument '--verbose' does not require leading dashes '--', updating to 'verbose'.
# Traceback (most recent call last):
#   File "/usr/local/bin/yolo", line 8, in <module>
#     sys.exit(entrypoint())
#   File "/content/ultralytics/ultralytics/cfg/__init__.py", line 524, in entrypoint
#     check_dict_alignment(full_args_dict, overrides)
#   File "/content/ultralytics/ultralytics/cfg/__init__.py", line 331, in check_dict_alignment
#     raise SyntaxError(string + CLI_HELP_MSG) from e
# SyntaxError: 'weights' is not a valid YOLO argument. Similar arguments are i.e. ['weight_decay=0.0005'].
#
#     Arguments received: ['yolo', 'task=detect', 'mode=train', 'data=/content/ultralytics/datasets/data.yaml', 'epochs=50', 'imgsz=640', 'batch=16', 'weights=yolov8n.pt', 'project=/content/ultralytics/runs/train', 'name=exp', '--verbose']. Ultralytics 'yolo' commands use the following syntax:
#
#         yolo TASK MODE ARGS
#
# ...

# %%
# Run training script with correct arguments
# !yolo task=detect mode=train data=/content/ultralytics/datasets/your-dataset.yaml epochs=50 imgsz=640 batch=16 model=yolov8n.pt project=/content/ultralytics/runs/train name=exp --verbose
# Out:
# WARNING ⚠️ argument '--verbose' does not require leading dashes '--', updating to 'verbose'.
# Ultralytics YOLOv8.2.31 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo task=detect mode=train data=/content/ultralytics/dataset/data.yaml epochs=50 imgsz=640 batch=16 model=yolov8n.pt project=/content/ultralytics/runs/train name=exp verbose
# Out:
# Ultralytics YOLOv8.2.31 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# List files in the output directory
# !ls /content/ultralytics/runs/train/exp
# Out:
# args.yaml  weights

# %%
# Display generated plots (loss, mAP, etc.)
from IPython.display import Image, display

display(Image('/content/ultralytics/runs/train/exp/results.png'))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/IPython/core/display.py in _data_and_metadata(self, always_both)
#    1299         try:
# -> 1300             b64_data = b2a_base64(self.data).decode('ascii')
#    1301         except TypeError:
#
# TypeError: a bytes-like object is required, not 'str'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/IPython/core/formatters.py in __call__(self, obj, include, exclude)
#     968
#     969             if method is not None:
# --> 970                 return method(include=include, exclude=exclude)
#     971             return None
#     972         else:
#
# ...
